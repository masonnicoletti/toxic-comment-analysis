# %% [markdown]
# # EDA
# ## Raw Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
data = pd.read_csv('../data/train.csv')

# %%
# Print data attributes
print(f"Number of rows: {data.shape[0]}")
print(f"Number of columns: {data.shape[1]}")

# Count NA Comments
num_na_comments = data['comment_text'].isna().sum()
print(f"Number of NA comments: {num_na_comments}")

# Count duplicates
duplicates = data.duplicated().sum()
print(f"Number of duplicates: {duplicates}")
# Out:
# Number of rows: 1599612
# Number of columns: 46
# Number of NA comments: 2
# Number of duplicates: 0

# %%
# Print NA values table
na_table = data.isna().sum()
print(f"NA Table:\n {na_table}")
# Out:
# NA Table:
#  id                                           0
# comment_text                                 2
# split                                        0
# created_date                                 0
# publication_id                               0
# parent_id                               692092
# article_id                                   0
# rating                                       0
# funny                                        0
# wow                                          0
# sad                                          0
# likes                                        0
# disagree                                     0
# toxicity                                     0
# severe_toxicity                              0
# obscene                                      0
# sexual_explicit                              0
# identity_attack                              0
# insult                                       0
# threat                                       0
# male                                   1241681
# female                                 1241681
# transgender                            1241681
# other_gender                           1241681
# heterosexual                           1241681
# homosexual_gay_or_lesbian              1241681
# bisexual                               1241681
# other_sexual_orientation               1241681
# christian                              1241681
# jewish                                 1241681
# muslim                                 1241681
# hindu                                  1241681
# buddhist                               1241681
# atheist                                1241681
# other_religion                         1241681
# black                                  1241681
# white                                  1241681
# asian                                  1241681
# latino                                 1241681
# other_race_or_ethnicity                1241681
# physical_disability                    1241681
# intellectual_or_learning_disability    1241681
# psychiatric_or_mental_illness          1241681
# other_disability                       1241681
# identity_annotator_count                     0
# toxicity_annotator_count                     0
# dtype: int64
